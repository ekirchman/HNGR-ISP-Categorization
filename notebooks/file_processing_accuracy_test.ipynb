# %%
import os
from PyPDF2 import PdfReader
import docx
import tiktoken

def limit_to_350_tokens(text, tokenizer):
    tokens = tokenizer.encode(text)
    if len(tokens) > 350:
        tokens = tokens[:350]
    return tokenizer.decode(tokens)

def extract_pdf_text(file_path, tokenizer):
    reader = PdfReader(file_path)
    text = ""
    for page in reader.pages:
        page_text = page.extract_text()
        if page_text:
            text += page_text
        if len(tokenizer.encode(text)) >= 350:
            break
    return limit_to_350_tokens(text, tokenizer)

def extract_docx_text(file_path, tokenizer):
    doc = docx.Document(file_path)
    text = " ".join([para.text for para in doc.paragraphs])
    return limit_to_350_tokens(text, tokenizer)

def test_process_files_in_folder(folder_path, tokenizer):
    total_files = 0
    empty_files = 0
    skipped_files = 0
    empty_files_list = []

    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            file_path = os.path.join(root, filename)
            file_extension = os.path.splitext(filename)[1].lower()

            if file_extension in ['.pdf', '.docx']:
                total_files += 1

                # Process file content in memory
                if file_extension == '.pdf':
                    text_excerpt = extract_pdf_text(file_path, tokenizer)
                elif file_extension == '.docx':
                    text_excerpt = extract_docx_text(file_path, tokenizer)

                # Check if the extracted text is empty
                if not text_excerpt.strip():
                    empty_files += 1
                    empty_files_list.append(file_path)  # Store full path
            else:
                skipped_files += 1

    non_empty_files = total_files - empty_files
    accuracy_percentage = (non_empty_files / total_files) * 100 if total_files > 0 else 0

    print("Process Files Testing Report")
    print(f"Total .pdf and .docx files in folder: {total_files}")
    print(f"Total empty .pdf and .docx files: {empty_files}")
    print(f"Accuracy: {accuracy_percentage:.2f}%")
    if empty_files > 0:
        print("List of empty files with full paths:")
        for file in empty_files_list:
            print(f"  - {file}")
    print(f"Total skipped non-PDF/DOCX files: {skipped_files}")
    print("\nNote: Files that are not .pdf or .docx were skipped in processing and are excluded from accuracy checks.")

tokenizer = tiktoken.get_encoding("cl100k_base")
folder_path = "../hngr-isps"
test_process_files_in_folder(folder_path, tokenizer)
# Out:
# Process Files Testing Report
# Total .pdf and .docx files in folder: 328
# Total empty .pdf and .docx files: 53
# Accuracy: 83.84%
# List of empty files with full paths:
#   - ../hngr-isps/ISP's for Josh Price/Lambrecht, Sarah--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh Price/Overgaard, Sara--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh Price/Baker, Shane--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh Price/Kim, John--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh Price/Herzog, Heidi--Final ISP.pdf
#   - ../hngr-isps/2021 ISP's for Josh-Copy/Oh, Sarah-Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(2)/Fletcher, Sarah--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(2)/Roembach-Clark, Haley--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(2)/Smith, Lauren--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(2)/Wilcox, Mary Ann--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(2)/Phillips, Rebekah--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(2)/Trim, Betsy--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(2)/Gess, Adam--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh/Haynes, Joshua--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh/Elzinga, Holly--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh/Tsai, Jean--Final ISP #1.pdf
#   - ../hngr-isps/ISP's for Josh/Van Wart, Justin--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh/Tsai, Jean--Final ISP #2.pdf
#   - ../hngr-isps/ISP's for Josh(3)/Wenger, Kimberly--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(3)/Durtsche, Kerstin--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(3)/Lutz, Bronwyn--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-41.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-42.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-1-1.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-46.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-50.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-45.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-22.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-36.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-34.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-18.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-24.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-8.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-5.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-28.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-15.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-39.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-10.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-38.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/DS_03_2019_Sophie_George_SeniorShow-12.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/IMG_2634.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/IMG-5682.pdf
#   - ../hngr-isps/ISP's for Josh-PDF-A-Copy/George-Art ISP/IMG_7824.pdf
#   - ../hngr-isps/ISP's for Josh(7)/Foote, Kara--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(7)/Johnson, Todd--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(7)/Cairns, Mandy--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(7)/Kennedy, Ellen--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(7)/Madigan, Jessica--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(7)/Smith, Adrin--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(7)/Strube, Jennifer--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(7)/Tungseth, Heidi--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(7)/Ingalls, Micah--Final ISP.pdf
#   - ../hngr-isps/ISP's for Josh(7)/McClain, Joshua--Final ISP.pdf
# Total skipped non-PDF/DOCX files: 16
#
# Note: Files that are not .pdf or .docx were skipped in processing and are excluded from accuracy checks.
